# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, log, when

# %%
# Initialize Spark Session
print("[INFO] Initializing Spark Session...")
spark = SparkSession.builder.appName("GDP_Prediction_Preprocessing").getOrCreate()
print("[INFO] Spark Session created successfully.")
# Out:
# [INFO] Initializing Spark Session...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/02 19:18:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [INFO] Spark Session created successfully.

# %%
project_root = os.path.dirname(os.getcwd())
project_root
# Out:
# '/uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE'

# %%
# Load Capital Stock dataset
file_path = os.path.join(base_path, "CapitalStockData.csv")

print(f"[INFO] Loading dataset: Capital Stock from {file_path}")
capital_stock_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Print schema and sample data
print(f"[INFO] Capital Stock dataset loaded successfully with {capital_stock_df.count()} rows.")
capital_stock_df.printSchema()
capital_stock_df.show(5)
# Out:
# [INFO] Loading dataset: Capital Stock from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/CapitalStockData.csv
# [INFO] Capital Stock dataset loaded successfully with 11640 rows.
# root
#  |-- isocode: string (nullable = true)
#  |-- ifscode: integer (nullable = true)
#  |-- country: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- igov_rppp: integer (nullable = true)
#  |-- kgov_rppp: integer (nullable = true)
#  |-- ipriv_rppp: integer (nullable = true)
#  |-- kpriv_rppp: integer (nullable = true)
#  |-- ippp_rppp: integer (nullable = true)
#  |-- kppp_rppp: integer (nullable = true)
#  |-- GDP_rppp: integer (nullable = true)
#  |-- igov_n: long (nullable = true)
#  |-- kgov_n: long (nullable = true)
#  |-- ipriv_n: integer (nullable = true)
#  |-- kpriv_n: long (nullable = true)
#  |-- kppp_n: integer (nullable = true)
#  |-- GDP_n: long (nullable = true)
#  |-- income: string (nullable = true)
#
# +-------+-------+-----------+----+---------+---------+----------+----------+---------+---------+--------+------+------+-------+-------+------+-----+--------------------+
# |isocode|ifscode|    country|year|igov_rppp|kgov_rppp|ipriv_rppp|kpriv_rppp|ippp_rppp|kppp_rppp|GDP_rppp|igov_n|kgov_n|ipriv_n|kpriv_n|kppp_n|GDP_n|              income|
# +-------+-------+-----------+----+---------+---------+----------+----------+---------+---------+--------+------+------+-------+-------+------+-----+--------------------+
# |    AFG|    512|Afghanistan|1960|        3|       50|         1|        15|     NULL|     NULL|    NULL|  NULL|  NULL|   NULL|   NULL|  NULL| NULL|Low Income Develo...|
# |    AFG|    512|Afghanistan|1961|        3|       52|         1|        15|     NULL|     NULL|    NULL|  NULL|  NULL|   NULL|   NULL|  NULL| NULL|Low Income Develo...|
# |    AFG|    512|Afghanistan|1962|        4|       54|         1|        16|     NULL|     NULL|    NULL|  NULL|  NULL|   NULL|   NULL|  NULL| NULL|Low Income Develo...|
# |    AFG|    512|Afghanistan|1963|        4|       56|         1|        17|     NULL|     NULL|    NULL|  NULL|  NULL|   NULL|   NULL|  NULL| NULL|Low Income Develo...|
# |    AFG|    512|Afghanistan|1964|        4|       59|         1|        17|     NULL|     NULL|    NULL|  NULL|  NULL|   NULL|   NULL|  NULL| NULL|Low Income Develo...|
# +-------+-------+-----------+----+---------+---------+----------+----------+---------+---------+--------+------+------+-------+-------+------+-----+--------------------+
# only showing top 5 rows

# %%
# Load Energy Use dataset
file_path = os.path.join(base_path, "energy_use.csv")

print(f"[INFO] Loading dataset: Energy Use from {file_path}")
energy_use_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Print schema and sample data
print(f"[INFO] Energy Use dataset loaded successfully with {energy_use_df.count()} rows.")
energy_use_df.printSchema()
energy_use_df.show(5)
# Out:
# [INFO] Loading dataset: Energy Use from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/energy_use.csv
# [INFO] Energy Use dataset loaded successfully with 266 rows.
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# +--------------------+-----------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |         Series Name|      Series Code|  Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +--------------------+-----------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |Energy use (kg of...|EG.USE.PCAP.KG.OE|   Afghanistan|         AFG|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Energy use (kg of...|EG.USE.PCAP.KG.OE|       Albania|         ALB|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|  785.1615259|  865.5924812|  762.7253617|   776.934749|   826.952081|  890.9533599|  923.7288675|  1010.819221|  864.1994597|  1149.536096|  989.2001485|  966.6832838|  1000.122013|  1018.263142|  916.5551906|  963.9271695|   921.893044|  927.7445187|  896.4377624|  813.2556955|   572.781844|  418.2866298|  412.3788805|  441.2492954|   417.034843|  447.8488703|  384.5949583|  426.6828191|  576.1836323|  580.4947642|  597.2652527|  660.0479841|  648.1683871|  715.4144831|  719.5843781|  706.8594077|  679.8617651|  710.7484985|  732.3166818|  729.1543727|  764.9686166|  687.8962599|   801.329975|  808.4558396|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Energy use (kg of...|EG.USE.PCAP.KG.OE|       Algeria|         DZA|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|  245.7249966|  278.6827431|  326.4718034|  342.7126781|  352.1129698|  383.9681715|   414.451251|  495.9876561|  609.8807678|  602.2015487|  633.8102912|   798.532262|   834.177939|  799.0337425|  806.2395223|  881.2117949|  844.2939112|  866.6929965|   836.985015|  874.2618659|  902.9859556|  902.0773104|  883.7712937|  833.2186873|  851.5581437|  808.5465995|  813.2345994|  828.3368214|  872.0428659|  873.5026684|  863.3434362|   911.280286|  955.6749109|  954.1322213|  979.1496026|  1032.456134|  1077.475848|  1070.543865|   1148.57475|  1107.727191|  1133.164863|  1220.981228|  1238.595673|  1318.008855|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Energy use (kg of...|EG.USE.PCAP.KG.OE|American Samoa|         ASM|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Energy use (kg of...|EG.USE.PCAP.KG.OE|       Andorra|         AND|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# +--------------------+-----------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# only showing top 5 rows

# %%
# Load Labor Force dataset
file_path = os.path.join(base_path, "labor_force.csv")

print(f"[INFO] Loading dataset: Labor Force from {file_path}")
labor_force_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Print schema and sample data
print(f"[INFO] Labor Force dataset loaded successfully with {labor_force_df.count()} rows.")
labor_force_df.printSchema()
labor_force_df.show(5)
# Out:
# [INFO] Loading dataset: Labor Force from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/labor_force.csv
# [INFO] Labor Force dataset loaded successfully with 266 rows.
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# +------------------+--------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |       Series Name|   Series Code|  Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +------------------+--------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |Labor force, total|SL.TLF.TOTL.IN|   Afghanistan|         AFG|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|      2978278|      3012953|      3252403|      3639934|      3933565|      4102970|      4241381|      4374653|      4511052|      4652787|      4685110|      4703525|      4947614|      5259920|      5459292|      5672338|      5937057|      6089718|      6273586|      6563261|      6822959|      7148944|      7518518|      7857574|      8229616|      8575264|      8883595|      9223903|      9215855|      9194531|      9060510|      9183905|      8617545|      8866507|
# |Labor force, total|SL.TLF.TOTL.IN|       Albania|         ALB|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|      1366650|      1419589|      1429286|      1407770|      1389340|      1363787|      1345509|      1360459|      1344507|      1324627|      1313953|      1300522|      1304298|      1290479|      1275726|      1259700|      1241897|      1222005|      1201455|      1247208|      1259163|      1376922|      1317638|      1217163|      1244156|      1295052|      1341701|      1363232|      1393620|      1415825|      1352399|      1367734|      1389262|      1376643|
# |Labor force, total|SL.TLF.TOTL.IN|       Algeria|         DZA|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|      6711330|      6973188|      7194753|      7426481|      7671789|      7906356|      8153158|      8366812|      8588043|      8827940|      9068833|      9306534|      9533572|      9752688|      9975430|     10190322|     10410056|     10632096|     10866131|     11105183|     11421278|     11586989|     11731223|     11845414|     11933136|     12055583|     12189762|     12357590|     12514356|     12667017|     12046917|     12323177|     13020342|     13174228|
# |Labor force, total|SL.TLF.TOTL.IN|American Samoa|         ASM|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Labor force, total|SL.TLF.TOTL.IN|       Andorra|         AND|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# +------------------+--------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# only showing top 5 rows

# %%
# Load Patents dataset
file_path = os.path.join(base_path, "patents_res_nonres.csv")

print(f"[INFO] Loading dataset: Patents from {file_path}")
patents_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Print schema and sample data
print(f"[INFO] Patents dataset loaded successfully with {patents_df.count()} rows.")
patents_df.printSchema()
patents_df.show(5)
# Out:
# [INFO] Loading dataset: Patents from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/patents_res_nonres.csv
# [INFO] Patents dataset loaded successfully with 532 rows.
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# +--------------------+-----------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |         Series Name|Series Code|  Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +--------------------+-----------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |Patent applicatio...|IP.PAT.NRES|   Afghanistan|         AFG|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Patent applicatio...|IP.PAT.NRES|       Albania|         ALB|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|            9|           ..|           ..|           ..|          120|          238|          391|           ..|          386|           ..|           ..|           ..|          361|           ..|            8|           ..|            4|            3|            5|            5|            8|            3|            1|           ..|            1|           ..|           ..|
# |Patent applicatio...|IP.PAT.NRES|       Algeria|         DZA|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|          349|          340|          320|          278|          345|           ..|           ..|           ..|          201|          200|          229|          170|          164|          138|          118|          134|          150|          207|          267|          248|          127|           94|          291|          296|          334|          465|          611|          765|           ..|           ..|          730|          803|          781|          722|          719|          716|          566|          594|          521|          525|          547|          581|           ..|           ..|
# |Patent applicatio...|IP.PAT.NRES|American Samoa|         ASM|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Patent applicatio...|IP.PAT.NRES|       Andorra|         AND|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|            3|            6|           10|           12|            5|            8|           ..|           ..|
# +--------------------+-----------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# only showing top 5 rows

# %%
# Load R&D Expenditure dataset
file_path = os.path.join(base_path, "R&D.csv")

print(f"[INFO] Loading dataset: R&D Expenditure from {file_path}")
rnd_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Print schema and sample data
print(f"[INFO] R&D Expenditure dataset loaded successfully with {rnd_df.count()} rows.")
rnd_df.printSchema()
rnd_df.show(5)
# Out:
# [INFO] Loading dataset: R&D Expenditure from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/R&D.csv
# [INFO] R&D Expenditure dataset loaded successfully with 266 rows.
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# +--------------------+-----------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |         Series Name|      Series Code|  Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +--------------------+-----------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |Researchers in R&...|SP.POP.SCIE.RD.P6|   Afghanistan|         AFG|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Researchers in R&...|SP.POP.SCIE.RD.P6|       Albania|         ALB|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|  157.6003265|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Researchers in R&...|SP.POP.SCIE.RD.P6|       Algeria|         DZA|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|   170.807663|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|  832.4227905|           ..|           ..|           ..|           ..|           ..|           ..|
# |Researchers in R&...|SP.POP.SCIE.RD.P6|American Samoa|         ASM|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|  85.80008698|  413.2302551|   155.703949|  104.4404602|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Researchers in R&...|SP.POP.SCIE.RD.P6|       Andorra|         AND|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# +--------------------+-----------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# only showing top 5 rows

# %%
# Load Unemployment dataset
file_path = os.path.join(base_path, "unemployed_ilo_estimate.csv")

print(f"[INFO] Loading dataset: Unemployment from {file_path}")
unemployment_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Print schema and sample data
print(f"[INFO] Unemployment dataset loaded successfully with {unemployment_df.count()} rows.")
unemployment_df.printSchema()
unemployment_df.show(5)
# Out:
# [INFO] Loading dataset: Unemployment from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# [INFO] Unemployment dataset loaded successfully with 266 rows.
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# +--------------------+--------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |         Series Name|   Series Code|  Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +--------------------+--------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |Unemployment, tot...|SL.UEM.TOTL.ZS|   Afghanistan|         AFG|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|         8.07|        8.011|        7.888|        7.822|        7.817|        7.867|        7.863|         7.89|        7.903|        7.935|        7.953|         7.93|         7.88|        7.899|        7.885|        7.914|        7.817|        7.878|        7.754|        7.753|        7.784|        7.856|         7.93|        7.915|        9.052|       10.133|       11.184|       11.196|       11.185|        11.71|       11.994|         14.1|       13.991|
# |Unemployment, tot...|SL.UEM.TOTL.ZS|       Albania|         ALB|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|       10.304|       30.007|       25.251|       20.835|       14.607|       13.928|       16.872|       20.042|       20.835|       19.023|        18.57|       17.891|       16.985|       16.306|       15.966|       15.626|       15.966|        13.06|       13.674|       14.086|       13.481|       13.376|       15.866|       18.055|       17.193|       15.418|       13.616|       12.304|       11.466|        11.69|       11.474|       10.137|       10.108|
# |Unemployment, tot...|SL.UEM.TOTL.ZS|       Algeria|         DZA|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|         20.6|        24.38|        26.23|        27.74|        31.84|       28.308|        25.43|       26.853|       28.548|        29.77|         27.3|         25.9|        23.72|        17.65|        15.27|        12.27|        13.79|        11.33|        10.16|         9.96|         9.96|        10.97|         9.82|       10.207|       11.206|       10.202|           12|       12.137|       12.259|       14.057|        13.63|       12.346|       11.701|
# |Unemployment, tot...|SL.UEM.TOTL.ZS|American Samoa|         ASM|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# |Unemployment, tot...|SL.UEM.TOTL.ZS|       Andorra|         AND|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|           ..|
# +--------------------+--------------+--------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# only showing top 5 rows

# %%
# Check Missing Values
print("\n[DEBUG] Checking missing values for: Capital Stock")
capital_stock_df.select([(col(c).isNull().cast("int")).alias(c) for c in capital_stock_df.columns]).summary("count").show()

print("\n[DEBUG] Checking missing values for: Energy Use")
energy_use_df.select([(col(c).isNull().cast("int")).alias(c) for c in energy_use_df.columns]).summary("count").show()

print("\n[DEBUG] Checking missing values for: Labor Force")
labor_force_df.select([(col(c).isNull().cast("int")).alias(c) for c in labor_force_df.columns]).summary("count").show()

print("\n[DEBUG] Checking missing values for: Patents")
patents_df.select([(col(c).isNull().cast("int")).alias(c) for c in patents_df.columns]).summary("count").show()

print("\n[DEBUG] Checking missing values for: R&D Expenditure")
rnd_df.select([(col(c).isNull().cast("int")).alias(c) for c in rnd_df.columns]).summary("count").show()

print("\n[DEBUG] Checking missing values for: Unemployment")
unemployment_df.select([(col(c).isNull().cast("int")).alias(c) for c in unemployment_df.columns]).summary("count").show()
# Out:
# [DEBUG] Checking missing values for: Capital Stock
# +-------+-------+-------+-------+-----+---------+---------+----------+----------+---------+---------+--------+------+------+-------+-------+------+-----+------+
# |summary|isocode|ifscode|country| year|igov_rppp|kgov_rppp|ipriv_rppp|kpriv_rppp|ippp_rppp|kppp_rppp|GDP_rppp|igov_n|kgov_n|ipriv_n|kpriv_n|kppp_n|GDP_n|income|
# +-------+-------+-------+-------+-----+---------+---------+----------+----------+---------+---------+--------+------+------+-------+-------+------+-----+------+
# |  count|  11640|  11640|  11640|11640|    11640|    11640|     11640|     11640|    11640|    11640|   11640| 11640| 11640|  11640|  11640| 11640|11640| 11640|
# +-------+-------+-------+-------+-----+---------+---------+----------+----------+---------+---------+--------+------+------+-------+-------+------+-----+------+
#
#
# [DEBUG] Checking missing values for: Energy Use
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |summary|Series Name|Series Code|Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |  count|        266|        266|         266|         266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
#
#
# [DEBUG] Checking missing values for: Labor Force
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |summary|Series Name|Series Code|Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |  count|        266|        266|         266|         266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
#
#
# [DEBUG] Checking missing values for: Patents
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |summary|Series Name|Series Code|Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |  count|        532|        532|         532|         532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|          532|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
#
#
# [DEBUG] Checking missing values for: R&D Expenditure
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |summary|Series Name|Series Code|Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |  count|        266|        266|         266|         266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
#
#
# [DEBUG] Checking missing values for: Unemployment
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |summary|Series Name|Series Code|Country Name|Country Code|1960 [YR1960]|1961 [YR1961]|1962 [YR1962]|1963 [YR1963]|1964 [YR1964]|1965 [YR1965]|1966 [YR1966]|1967 [YR1967]|1968 [YR1968]|1969 [YR1969]|1970 [YR1970]|1971 [YR1971]|1972 [YR1972]|1973 [YR1973]|1974 [YR1974]|1975 [YR1975]|1976 [YR1976]|1977 [YR1977]|1978 [YR1978]|1979 [YR1979]|1980 [YR1980]|1981 [YR1981]|1982 [YR1982]|1983 [YR1983]|1984 [YR1984]|1985 [YR1985]|1986 [YR1986]|1987 [YR1987]|1988 [YR1988]|1989 [YR1989]|1990 [YR1990]|1991 [YR1991]|1992 [YR1992]|1993 [YR1993]|1994 [YR1994]|1995 [YR1995]|1996 [YR1996]|1997 [YR1997]|1998 [YR1998]|1999 [YR1999]|2000 [YR2000]|2001 [YR2001]|2002 [YR2002]|2003 [YR2003]|2004 [YR2004]|2005 [YR2005]|2006 [YR2006]|2007 [YR2007]|2008 [YR2008]|2009 [YR2009]|2010 [YR2010]|2011 [YR2011]|2012 [YR2012]|2013 [YR2013]|2014 [YR2014]|2015 [YR2015]|2016 [YR2016]|2017 [YR2017]|2018 [YR2018]|2019 [YR2019]|2020 [YR2020]|2021 [YR2021]|2022 [YR2022]|2023 [YR2023]|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+
# |  count|        266|        266|         266|         266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|          266|
# +-------+-----------+-----------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+

# %%
# Standardize Column Names & Handle Missing Values
print("[INFO] Standardizing column names and handling missing values for: Capital Stock")
capital_stock_df = capital_stock_df.select([col(c).alias(c.replace(" ", "_").lower()) for c in capital_stock_df.columns])

for column in capital_stock_df.columns:
    capital_stock_df = capital_stock_df.withColumn(column, when(col(column).isNull(), capital_stock_df.agg({column: "mean"}).collect()[0][0]).otherwise(col(column)))

print("[INFO] Standardization and missing value handling completed for Capital Stock")
# Out:
# [INFO] Standardizing column names and handling missing values for: Capital Stock
# [INFO] Standardization and missing value handling completed for Capital Stock

# %%
print("[INFO] Standardizing column names and handling missing values for: Energy Use")
energy_use_df = energy_use_df.select([col(c).alias(c.replace(" ", "_").lower()) for c in energy_use_df.columns])

for column in energy_use_df.columns:
    energy_use_df = energy_use_df.withColumn(column, when(col(column).isNull(), energy_use_df.agg({column: "mean"}).collect()[0][0]).otherwise(col(column)))

print("[INFO] Standardization and missing value handling completed for Energy Use")
# Out:
# [INFO] Standardizing column names and handling missing values for: Energy Use
# [INFO] Standardization and missing value handling completed for Energy Use

# %%
print("[INFO] Standardizing column names and handling missing values for: Labor Force")
labor_force_df = labor_force_df.select([col(c).alias(c.replace(" ", "_").lower()) for c in labor_force_df.columns])

for column in labor_force_df.columns:
    labor_force_df = labor_force_df.withColumn(column, when(col(column).isNull(), labor_force_df.agg({column: "mean"}).collect()[0][0]).otherwise(col(column)))

print("[INFO] Standardization and missing value handling completed for Labor Force")
# Out:
# [INFO] Standardizing column names and handling missing values for: Labor Force
# [INFO] Standardization and missing value handling completed for Labor Force

# %%
print("[INFO] Standardizing column names and handling missing values for: Patents")
patents_df = patents_df.select([col(c).alias(c.replace(" ", "_").lower()) for c in patents_df.columns])

for column in patents_df.columns:
    patents_df = patents_df.withColumn(column, when(col(column).isNull(), patents_df.agg({column: "mean"}).collect()[0][0]).otherwise(col(column)))

print("[INFO] Standardization and missing value handling completed for Patents")
# Out:
# [INFO] Standardizing column names and handling missing values for: Patents
# [INFO] Standardization and missing value handling completed for Patents

# %%
print("[INFO] Standardizing column names and handling missing values for: R&D Expenditure")
rnd_df = rnd_df.select([col(c).alias(c.replace(" ", "_").lower()) for c in rnd_df.columns])

for column in rnd_df.columns:
    rnd_df = rnd_df.withColumn(column, when(col(column).isNull(), rnd_df.agg({column: "mean"}).collect()[0][0]).otherwise(col(column)))

print("[INFO] Standardization and missing value handling completed for R&D Expenditure")
# Out:
# [INFO] Standardizing column names and handling missing values for: R&D Expenditure
# [INFO] Standardization and missing value handling completed for R&D Expenditure

# %%
print("[INFO] Standardizing column names and handling missing values for: Unemployment")
unemployment_df = unemployment_df.select([col(c).alias(c.replace(" ", "_").lower()) for c in unemployment_df.columns])

for column in unemployment_df.columns:
    unemployment_df = unemployment_df.withColumn(column, when(col(column).isNull(), unemployment_df.agg({column: "mean"}).collect()[0][0]).otherwise(col(column)))

print("[INFO] Standardization and missing value handling completed for Unemployment")
# Out:
# [INFO] Standardizing column names and handling missing values for: Unemployment
# [INFO] Standardization and missing value handling completed for Unemployment

# %%
dfs = {
    "Capital Stock": capital_stock_df,
    "Energy Use": energy_use_df,
    "Labor Force": labor_force_df,
    "Patents": patents_df,
    "R&D Expenditure": rnd_df,
    "Unemployment": unemployment_df
}
print("[INFO] All datasets loaded successfully.")
# Out:
# [INFO] All datasets loaded successfully.

# %%
for name, df in dfs.items():
    print(f"[INFO] Loading dataset: {name} from {path}")
    df = spark.read.csv(path, header=True, inferSchema=True)
    df.printSchema()
# Out:
# [INFO] Loading dataset: Capital Stock from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# [INFO] Loading dataset: Energy Use from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# [INFO] Loading dataset: Labor Force from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# [INFO] Loading dataset: Patents from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# [INFO] Loading dataset: R&D Expenditure from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)
#
# [INFO] Loading dataset: Unemployment from /uufs/chpc.utah.edu/common/home/u1463636/CS6964/GDP_Prediction_ALITE/data/raw/unemployed_ilo_estimate.csv
# root
#  |-- Series Name: string (nullable = true)
#  |-- Series Code: string (nullable = true)
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- 1960 [YR1960]: string (nullable = true)
#  |-- 1961 [YR1961]: string (nullable = true)
#  |-- 1962 [YR1962]: string (nullable = true)
#  |-- 1963 [YR1963]: string (nullable = true)
#  |-- 1964 [YR1964]: string (nullable = true)
#  |-- 1965 [YR1965]: string (nullable = true)
#  |-- 1966 [YR1966]: string (nullable = true)
#  |-- 1967 [YR1967]: string (nullable = true)
#  |-- 1968 [YR1968]: string (nullable = true)
#  |-- 1969 [YR1969]: string (nullable = true)
#  |-- 1970 [YR1970]: string (nullable = true)
#  |-- 1971 [YR1971]: string (nullable = true)
#  |-- 1972 [YR1972]: string (nullable = true)
#  |-- 1973 [YR1973]: string (nullable = true)
#  |-- 1974 [YR1974]: string (nullable = true)
#  |-- 1975 [YR1975]: string (nullable = true)
#  |-- 1976 [YR1976]: string (nullable = true)
#  |-- 1977 [YR1977]: string (nullable = true)
#  |-- 1978 [YR1978]: string (nullable = true)
#  |-- 1979 [YR1979]: string (nullable = true)
#  |-- 1980 [YR1980]: string (nullable = true)
#  |-- 1981 [YR1981]: string (nullable = true)
#  |-- 1982 [YR1982]: string (nullable = true)
#  |-- 1983 [YR1983]: string (nullable = true)
#  |-- 1984 [YR1984]: string (nullable = true)
#  |-- 1985 [YR1985]: string (nullable = true)
#  |-- 1986 [YR1986]: string (nullable = true)
#  |-- 1987 [YR1987]: string (nullable = true)
#  |-- 1988 [YR1988]: string (nullable = true)
#  |-- 1989 [YR1989]: string (nullable = true)
#  |-- 1990 [YR1990]: string (nullable = true)
#  |-- 1991 [YR1991]: string (nullable = true)
#  |-- 1992 [YR1992]: string (nullable = true)
#  |-- 1993 [YR1993]: string (nullable = true)
#  |-- 1994 [YR1994]: string (nullable = true)
#  |-- 1995 [YR1995]: string (nullable = true)
#  |-- 1996 [YR1996]: string (nullable = true)
#  |-- 1997 [YR1997]: string (nullable = true)
#  |-- 1998 [YR1998]: string (nullable = true)
#  |-- 1999 [YR1999]: string (nullable = true)
#  |-- 2000 [YR2000]: string (nullable = true)
#  |-- 2001 [YR2001]: string (nullable = true)
#  |-- 2002 [YR2002]: string (nullable = true)
#  |-- 2003 [YR2003]: string (nullable = true)
#  |-- 2004 [YR2004]: string (nullable = true)
#  |-- 2005 [YR2005]: string (nullable = true)
#  |-- 2006 [YR2006]: string (nullable = true)
#  |-- 2007 [YR2007]: string (nullable = true)
#  |-- 2008 [YR2008]: string (nullable = true)
#  |-- 2009 [YR2009]: string (nullable = true)
#  |-- 2010 [YR2010]: string (nullable = true)
#  |-- 2011 [YR2011]: string (nullable = true)
#  |-- 2012 [YR2012]: string (nullable = true)
#  |-- 2013 [YR2013]: string (nullable = true)
#  |-- 2014 [YR2014]: string (nullable = true)
#  |-- 2015 [YR2015]: string (nullable = true)
#  |-- 2016 [YR2016]: string (nullable = true)
#  |-- 2017 [YR2017]: string (nullable = true)
#  |-- 2018 [YR2018]: string (nullable = true)
#  |-- 2019 [YR2019]: string (nullable = true)
#  |-- 2020 [YR2020]: string (nullable = true)
#  |-- 2021 [YR2021]: string (nullable = true)
#  |-- 2022 [YR2022]: string (nullable = true)
#  |-- 2023 [YR2023]: string (nullable = true)

# %% [markdown]
# ### ALITE-Based Integration

# %%
from alite import Alite
import pandas as pd

# Initialize ALITE
alite = Alite()

# Load datasets into ALITE from dictionary
for name, df in dfs.items():
    alite.add_dataframe(name, df, key=["Country Code", "Year"])

# Perform Automatic Integration
integrated_data = alite.integrate()

# Save the Merged Data
integrated_data.to_csv("data/alite_merged.csv", index=False)

print("ALITE Integration Complete!")

# %% [markdown]
# ### Simple Join

# %%
from pyspark.sql import SparkSession

# Start with the first dataset
merged_data = dfs["Capital Stock"]

# Perform Outer Joins with Other Datasets
for name, df in dfs.items():
    if name != "Capital Stock":
        merged_data = merged_data.join(df, ["Countrycode", "Year"], "outer")

# Save Merged Data
merged_data.write.csv("data/simple_join_merged.csv", header=True)

print("Simple Join Integration Complete!")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[25], line 9
#       7 for name, df in dfs.items():
#       8     if name != "Capital Stock":
# ----> 9         merged_data = merged_data.join(df, ["Countrycode", "Year"], "outer")
#      11 # Save Merged Data
#      12 merged_data.write.csv("data/simple_join_merged.csv", header=True)
#
# File /uufs/chpc.utah.edu/sys/installdir/miniconda3/pyspark-3.5/lib/python3.11/site-packages/pyspark/sql/dataframe.py:2487, in DataFrame.join(self, other, on, how)
#    2485         on = self._jseq([])
#    2486     assert isinstance(how, str), "how should be a string"
# -> 2487     jdf = self._jdf.join(other._jdf, on, how)
#    2488 return DataFrame(jdf, self.sparkSession)
#
# File /uufs/chpc.utah.edu/sys/installdir/miniconda3/pyspark-3.5/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /uufs/chpc.utah.edu/sys/installdir/miniconda3/pyspark-3.5/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_USING_COLUMN_FOR_JOIN] USING column `Countrycode` cannot be resolved on the left side of the join. The left-side columns: [`country`, `gdp_n`, `gdp_rppp`, `ifscode`, `igov_n`, `igov_rppp`, `income`, `ippp_rppp`, `ipriv_n`, `ipriv_rppp`, `isocode`, `kgov_n`, `kgov_rppp`, `kppp_n`, `kppp_rppp`, `kpriv_n`, `kpriv_rppp`, `year`].

# %%
import pandas as pd
import time

# Load the merged datasets
alite_merged = pd.read_csv("data/alite_merged.csv")
simple_join_merged = pd.read_csv("data/simple_join_merged.csv")

# Function to evaluate dataset
def evaluate_dataset(df, name):
    print(f"\n### Evaluation of {name} ###")
    print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
    missing_values = df.isnull().sum().sum()
    total_values = df.size
    missing_percentage = (missing_values / total_values) * 100
    print(f"Missing Values: {missing_values} ({missing_percentage:.2f}%)")
    print(f"Sample Data:\n{df.head(3)}\n")

# Measure Time for ALITE Integration
start_time = time.time()
alite_merged = pd.read_csv("data/alite_merged.csv")  # Simulating ALITE read time
alite_time = time.time() - start_time

# Measure Time for Simple Join Integration
start_time = time.time()
simple_join_merged = pd.read_csv("data/simple_join_merged.csv")  # Simulating Join read time
simple_join_time = time.time() - start_time

# Evaluate datasets
evaluate_dataset(alite_merged, "ALITE Integrated Data")
evaluate_dataset(simple_join_merged, "Simple Join Integrated Data")

# Performance Comparison
print("\n### Performance Comparison ###")
print(f"ALITE Integration Time: {alite_time:.4f} seconds")
print(f"Simple Join Integration Time: {simple_join_time:.4f} seconds")
print(f"Schema Consistency: {'Same' if list(alite_merged.columns) == list(simple_join_merged.columns) else 'Different'}")
